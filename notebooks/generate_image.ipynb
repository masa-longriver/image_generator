# %%
import os 
import sys

sys.path.append(os.path.dirname(os.getcwd()))

from IPython.display import Image, display

from config import load_config
from scripts import generate_from_text_by_dall_e_3, save_image

# %%
config = load_config()
print(config)
# Out:
# {'size': '1792x1024', 'style': 'vivid', 'file_nm': 'generative_AI_school'}

# %%
prompt = """
A young female Generative AI Engineer standing amidst a flurry of cherry 
blossom petals, her hands outstretched as if weaving intricate patterns. 
From her hands, a vibrant web of neural networks, mathematical equations, 
and graph structures emerges in a mesmerizing array of blues, greens, and 
purples. These cool-toned hues create a striking contrast against the soft 
pinks and whites of the cherry blossoms, emphasizing the distinctive nature 
of the generative AI systems. The engineer's expression is one of deep 
concentration and creativity, as the spring breeze gently tosses her hair 
and the cherry blossom petals around her. In the background, fully bloomed 
cherry trees in soft shades of pink and white create a dreamy, almost 
ethereal atmosphere. The image conveys a sense of harmony between the 
natural beauty of spring and the innovative, cutting-edge world of 
generative AI technology.
"""

# %%
# # 画像を生成
# url = generate_from_text_by_dall_e_3(prompt, config['size'], config['style'])
# save_image(url, os.path.join("../logs/images", f"{config['file_nm']}.png"))

# # プロンプトを保存
# prompt_file_path = os.path.join("../logs/prompts", f"{config['file_nm']}.txt")
# with open(prompt_file_path, 'w', encoding='utf-8') as file:
#     file.write(prompt)

image_path = os.path.join("../logs/images", f"{config['file_nm']}.png")
display(Image(filename=image_path))
